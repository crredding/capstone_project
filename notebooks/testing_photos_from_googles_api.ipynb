# %%
cd ../website
# Out:
# /Users/ReddingSkinnyRobot/Galvanize/coffee_filter/website

# %%
import pandas as pd
import numpy as np
import yaml
import json, requests
from recommender_model import *
from PIL import Image
import base64
from pathlib import Path

# %%
cd ../API_functions/
# Out:
# /Users/ReddingSkinnyRobot/Galvanize/coffee_filter/API_functions

# %%
from google_api_functions import *

# %%
with open('/Users/ReddingSkinnyRobot/.secrets/google_api.yaml') as f:
    google_secrets = yaml.load(f)

# %%
#DONT EVER DELETE!!!
with open('../website/static/shop_images/0.jpg', 'rb') as f:
    byt = base64.decodebytes(f.read())
    bio = BytesIO(byt)
Image.open(bio)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-f3cd3b498638> in <module>()
#       3     byt = base64.decodebytes(f.read())
#       4     bio = BytesIO(byt)
# ----> 5 Image.open(bio)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2517         fp.close()
#    2518     raise IOError("cannot identify image file %r"
# -> 2519                   % (filename if filename else fp))
#    2520
#    2521 #
#
# OSError: cannot identify image file <_io.BytesIO object at 0x1161d60a0>

# %%
x = get_google_photo(47.613288, -122.308731, 'Tougo Coffee Co.', google_secrets['key'])

# %%
type(x)
# Out:
# bytes

# %%
image = Image.open(BytesIO(x))

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x10E0BE908>

# %%
shop_id = 10
image = Path('../shop_images/{}.jpg'.format(shop_id))

# %%
with open('../static/images/default_shop_image.jpg', 'rb') as f1:
    f2 = f1.read()
    default_shop_image = base64.b64encode(bytearray(f2)).decode()
